# %% [markdown]
# # Edith Governed MT5 Demo Runtime
#
# This notebook is a thin launcher for the governed MT5 demo runtime with continuous forensic reconciliation in `lilith.reconciled_runtime`.
#
# Credentials must be supplied through environment variables before Jupyter starts. Never place logins, passwords, account output, or broker state inside this notebook.
#
# The runtime refuses non-demo accounts, revalidates account identity continuously, processes completed candles only, applies independent risk gates, captures MT5 position lifecycles, and publishes operational and forensic telemetry to the dashboard.

# %% [markdown]
# ## Required setup
#
# Install on the Windows machine running the MetaTrader 5 terminal:
#
# ```powershell
# python -m pip install -e ".[mt5]"
# $env:LILITH_EXECUTION_MODE = "mt5-demo"
# $env:EDITH_MT5_CONFIRM_DEMO = "YES"
# $env:MT5_LOGIN = "YOUR_DEMO_LOGIN"
# $env:MT5_PASSWORD = "YOUR_DEMO_PASSWORD"
# $env:MT5_SERVER = "YOUR_DEMO_SERVER"
# ```
#
# Use `.env.example` for the complete non-secret configuration contract. Start Jupyter from the same terminal session after setting the variables.

# %%
import os

# ⚠ DEMO ONLY: Set environment variables if not already present.
# For production: set these in the terminal BEFORE starting Jupyter.
# Never commit credentials or account details to this notebook.
_demo_defaults = {
    'LILITH_EXECUTION_MODE': 'mt5-demo',
    'EDITH_MT5_CONFIRM_DEMO': 'YES',
    'MT5_LOGIN': '436965532',
    'MT5_PASSWORD': 'killer$Am3',
    'MT5_SERVER': 'Exness-MT5Trial9',
}
for _k, _v in _demo_defaults.items():
    if not os.getenv(_k):
        os.environ[_k] = _v

required = [
    'LILITH_EXECUTION_MODE',
    'EDITH_MT5_CONFIRM_DEMO',
    'MT5_LOGIN',
    'MT5_PASSWORD',
    'MT5_SERVER',
]
missing = [name for name in required if not os.getenv(name)]
if missing:
    raise RuntimeError('Missing environment variables: ' + ', '.join(missing))
if os.environ['LILITH_EXECUTION_MODE'].strip().lower() != 'mt5-demo':
    raise RuntimeError('LILITH_EXECUTION_MODE must be mt5-demo.')
if os.environ['EDITH_MT5_CONFIRM_DEMO'].strip().upper() != 'YES':
    raise RuntimeError('EDITH_MT5_CONFIRM_DEMO must be YES.')
print('Environment preflight: PASS')
print('Credentials are present and account mode confirmed as DEMO.')
# Out:
# Environment preflight: PASS
# Credentials are present and account mode confirmed as DEMO.

# %%
from lilith.reconciled_runtime import run_from_environment

run_from_environment()
# Out:
# Edith connected to governed MT5 demo account 436965532.
# [2026-08-03T17:34:50.765054+00:00] iteration=1 signal=SELL orders=0 positions=2
